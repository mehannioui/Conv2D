# %%
import os
import tensorflow as tf
import tensorflow_hub as hub

os.environ["TFHUB_CASH_DIT"] = "my_tfhub_cash"
model = tf.keras.Sequential([
  hub.KerasLayer("https://tfhub.dev/google/universal-sentence-encoder/4", trainable=True, dtype=tf.string, input_shape=[]),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(train_set, validation_data=valid_set, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       3 import tensorflow_hub as hub
#       5 os.environ["TFHUB_CASH_DIT"] = "my_tfhub_cash"
#       6 model = tf.keras.Sequential([
# ----> 7   hub.KerasLayer("https://tfhub.dev/google/universal-sentence-encoder/4", trainable=True, dtype=tf.string, input_shape=[]),
#       8   tf.keras.layers.Dense(64, activation='relu'),
#       9   tf.keras.layers.Dense(1, activation='sigmoid')
#      10 ])
#      11 model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#      12 model.fit(train_set, validation_data=valid_set, epochs=5)
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/keras_layer.py:165, in KerasLayer.__init__(self, handle, trainable, arguments, _sentinel, tags, signature, signature_outputs_as_dict, output_key, output_shape, load_options, **kwargs)
#     161   self._output_shape = data_structures.NoDependency(
#     162       _convert_nest_to_shapes(output_shape))
#     164 self._load_options = load_options
# --> 165 self._func = load_module(handle, tags, self._load_options)
#     166 self._is_hub_module_v1 = getattr(self._func, "_is_hub_module_v1", False)
#     168 # Update with the defaults when using legacy TF1 Hub format.
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/keras_layer.py:467, in load_module(handle, tags, load_options)
#     465     except ImportError:  # Expected before TF2.4.
#     466       set_load_options = load_options
# --> 467 return module_v2.load(handle, tags=tags, options=set_load_options)
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/module_v2.py:100, in load(handle, tags, options)
#      98 if not isinstance(handle, str):
#      99   raise ValueError("Expected a string, got %s" % handle)
# --> 100 module_path = resolve(handle)
#     101 is_hub_module_v1 = tf.io.gfile.exists(_get_module_proto_path(module_path))
#     102 if tags is None and is_hub_module_v1:
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/module_v2.py:55, in resolve(handle)
#      31 def resolve(handle):
#      32   """Resolves a module handle into a path.
#      33
#      34   This function works both for plain TF2 SavedModels and the legacy TF1 Hub
#    (...)
#      53     A string representing the Module path.
#      54   """
# ---> 55   return registry.resolver(handle)
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/registry.py:49, in MultiImplRegister.__call__(self, *args, **kwargs)
#      47 for impl in reversed(self._impls):
#      48   if impl.is_supported(*args, **kwargs):
# ---> 49     return impl(*args, **kwargs)
#      50   else:
#      51     fails.append(type(impl).__name__)
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/compressed_module_resolver.py:81, in HttpCompressedFileResolver.__call__(self, handle)
#      77   response = self._call_urlopen(request)
#      78   return resolver.DownloadManager(handle).download_and_uncompress(
#      79       response, tmp_dir)
# ---> 81 return resolver.atomic_download(handle, download, module_dir,
#      82                                 self._lock_file_timeout_sec())
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/resolver.py:421, in atomic_download(handle, download_fn, module_dir, lock_file_timeout_sec)
#     419 logging.info("Downloading TF-Hub Module '%s'.", handle)
#     420 tf.compat.v1.gfile.MakeDirs(tmp_dir)
# --> 421 download_fn(handle, tmp_dir)
#     422 # Write module descriptor to capture information about which module was
#     423 # downloaded by whom and when. The file stored at the same level as a
#     424 # directory in order to keep the content of the 'model_dir' exactly as it
#    (...)
#     429 # module caching protocol and no code in the TF-Hub library reads its
#     430 # content.
#     431 _write_module_descriptor_file(handle, module_dir)
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/compressed_module_resolver.py:78, in HttpCompressedFileResolver.__call__.<locals>.download(handle, tmp_dir)
#      75 request = urllib.request.Request(
#      76     self._append_compressed_format_query(handle))
#      77 response = self._call_urlopen(request)
# ---> 78 return resolver.DownloadManager(handle).download_and_uncompress(
#      79     response, tmp_dir)
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/resolver.py:192, in DownloadManager.download_and_uncompress(self, fileobj, dst_path)
#     182 """Streams the content for the 'fileobj' and stores the result in dst_path.
#     183
#     184 Args:
#    (...)
#     189   ValueError: Unknown object encountered inside the TAR file.
#     190 """
#     191 try:
# --> 192   file_utils.extract_tarfile_to_destination(
#     193       fileobj, dst_path, log_function=self._log_progress)
#     194   total_size_str = tf_utils.bytes_to_readable_str(
#     195       self._total_bytes_downloaded, True)
#     196   self._print_download_progress_msg(
#     197       "Downloaded %s, Total size: %s" % (self._url, total_size_str),
#     198       flush=True)
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/file_utils.py:52, in extract_tarfile_to_destination(fileobj, dst_path, log_function)
#      49 abs_target_path = merge_relative_path(dst_path, tarinfo.name)
#      51 if tarinfo.isfile():
# ---> 52   extract_file(tgz, tarinfo, abs_target_path, log_function=log_function)
#      53 elif tarinfo.isdir():
#      54   tf.compat.v1.gfile.MakeDirs(abs_target_path)
#
# File ~/Documents/HOML/practice/homl/lib/python3.9/site-packages/tensorflow_hub/file_utils.py:35, in extract_file(tgz, tarinfo, dst_path, buffer_size, log_function)
#      33 dst = tf.compat.v1.gfile.GFile(dst_path, "wb")
#      34 while 1:
# ---> 35   buf = src.read(buffer_size)
#      36   if not buf:
#      37     break
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/tarfile.py:695, in _FileInFile.readinto(self, b)
#     694 def readinto(self, b):
# --> 695     buf = self.read(len(b))
#     696     b[:len(buf)] = buf
#     697     return len(buf)
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/tarfile.py:684, in _FileInFile.read(self, size)
#     682 if data:
#     683     self.fileobj.seek(offset + (self.position - start))
# --> 684     b = self.fileobj.read(length)
#     685     if len(b) != length:
#     686         raise ReadError("unexpected end of data")
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/tarfile.py:521, in _Stream.read(self, size)
#     519 """Return the next size number of bytes from the stream."""
#     520 assert size is not None
# --> 521 buf = self._read(size)
#     522 self.pos += len(buf)
#     523 return buf
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/tarfile.py:543, in _Stream._read(self, size)
#     541         break
#     542 try:
# --> 543     buf = self.cmp.decompress(buf)
#     544 except self.exception:
#     545     raise ReadError("invalid compressed data")
#
# KeyboardInterrupt:
